# %%
import os
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        raw_data = f.read()
    result = chardet.detect(raw_data)
    return result['encoding']

def convert_encoding(input_folder, output_folder, target_encoding='utf-8'):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        # Skip hidden files such as .DS_Store
        if filename.startswith('.'):
            continue
        
        file_path = os.path.join(input_folder, filename)

        if os.path.isfile(file_path):
            # Detect original encoding
            original_encoding = detect_encoding(file_path)
            print(f"Converting {filename}: Detected {original_encoding}")

            # Read file with the detected encoding
            with open(file_path, 'r', encoding=original_encoding, errors='ignore') as f:
                content = f.read()

            # Create a subfolder for this file inside the output folder
            file_base_name = os.path.splitext(filename)[0]
            file_subfolder = os.path.join(output_folder, file_base_name)
            if not os.path.exists(file_subfolder):
                os.makedirs(file_subfolder)
            
            # Save file with new encoding inside the new subfolder
            output_file_path = os.path.join(file_subfolder, filename)
            with open(output_file_path, 'w', encoding=target_encoding) as f:
                f.write(content)
            print(f"File {filename} converted to {target_encoding} and saved at {output_file_path}")

# Example usage:
input_folder = r'/Users/jean.barkoczy/Documents/BaseCompleta'
output_folder = r'/Users/jean.barkoczy/Documents/BaseCompleta/Trata'
target_encoding = 'utf-8'

convert_encoding(input_folder, output_folder, target_encoding)
# Out:
# Converting Ses_seg_prov_det.csv: Detected ascii
# File Ses_seg_prov_det.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_seg_prov_det/Ses_seg_prov_det.csv
# Converting SES_Balanco.csv: Detected ascii
# File SES_Balanco.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/SES_Balanco/SES_Balanco.csv
# Converting ses_valoresresmovgrupos.csv: Detected ascii
# File ses_valoresresmovgrupos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_valoresresmovgrupos/ses_valoresresmovgrupos.csv
# Converting ses_provramos.csv: Detected ascii
# File ses_provramos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_provramos/ses_provramos.csv
# Converting ses_pgbl_resgates.csv: Detected ascii
# File ses_pgbl_resgates.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_pgbl_resgates/ses_pgbl_resgates.csv
# Converting ses_prev_cap_uf.csv: Detected ascii
# File ses_prev_cap_uf.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_prev_cap_uf/ses_prev_cap_uf.csv
# Converting Ses_Administradores.csv: Detected ISO-8859-1
# File Ses_Administradores.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_Administradores/Ses_Administradores.csv
# Converting ses_quantprev_part.csv: Detected ascii
# File ses_quantprev_part.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_quantprev_part/ses_quantprev_part.csv
# Converting ses_contatos.csv: Detected Windows-1252
# File ses_contatos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_contatos/ses_contatos.csv
# Converting Ses_grupos_economicos.csv: Detected Windows-1252
# File Ses_grupos_economicos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_grupos_economicos/Ses_grupos_economicos.csv
# Converting Ses_prov.csv: Detected ascii
# File Ses_prov.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_prov/Ses_prov.csv
# Converting Ses_diversos.csv: Detected ascii
# File Ses_diversos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_diversos/Ses_diversos.csv
# Converting Ses_Contrib_Benef.csv: Detected ascii
# File Ses_Contrib_Benef.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_Contrib_Benef/Ses_Contrib_Benef.csv
# Converting ses_quantprev_benef.csv: Detected ascii
# File ses_quantprev_benef.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_quantprev_benef/ses_quantprev_benef.csv
# Converting ses_cap_uf.csv: Detected ascii
# File ses_cap_uf.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_cap_uf/ses_cap_uf.csv
# Converting SES_prov_segprev.csv: Detected ascii
# File SES_prov_segprev.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/SES_prov_segprev/SES_prov_segprev.csv
# Converting Ses_cias.csv: Detected Windows-1252
# File Ses_cias.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_cias/Ses_cias.csv
# Converting ses_prev_uf.csv: Detected ascii
# File ses_prev_uf.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_prev_uf/ses_prev_uf.csv
# Converting Ses_vgbl_resgates.csv: Detected ascii
# File Ses_vgbl_resgates.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_vgbl_resgates/Ses_vgbl_resgates.csv
# Converting ses_pgbl_fundos.csv: Detected ascii
# File ses_pgbl_fundos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_pgbl_fundos/ses_pgbl_fundos.csv
# Converting ses_pgbl_contrib.csv: Detected ascii
# File ses_pgbl_contrib.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_pgbl_contrib/ses_pgbl_contrib.csv
# Converting LimiteRetProxVig.csv: Detected ISO-8859-1
# File LimiteRetProxVig.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/LimiteRetProxVig/LimiteRetProxVig.csv
# Converting ses_gruposramos.csv: Detected ISO-8859-1
# File ses_gruposramos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_gruposramos/ses_gruposramos.csv
# Converting Ses_Dados_Cap.csv: Detected ISO-8859-1
# File Ses_Dados_Cap.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_Dados_Cap/Ses_Dados_Cap.csv
# Converting Ses_ramos.csv: Detected Windows-1252
# File Ses_ramos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_ramos/Ses_ramos.csv
# Converting Ses_dependencias.csv: Detected Windows-1252
# File Ses_dependencias.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_dependencias/Ses_dependencias.csv
# Converting Ses_vgbl_fundos.csv: Detected ascii
# File Ses_vgbl_fundos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_vgbl_fundos/Ses_vgbl_fundos.csv
# Converting Ses_Cessoes_Recebidas.csv: Detected ascii
# File Ses_Cessoes_Recebidas.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_Cessoes_Recebidas/Ses_Cessoes_Recebidas.csv
# Converting Ses_seguros.csv: Detected ascii
# File Ses_seguros.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_seguros/Ses_seguros.csv
# Converting ses_prev_trad_resgates.csv: Detected ascii
# File ses_prev_trad_resgates.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_prev_trad_resgates/ses_prev_trad_resgates.csv
# Converting Ses_rmovram.csv: Detected ascii
# File Ses_rmovram.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_rmovram/Ses_rmovram.csv
# Converting ses_quantcap.csv: Detected ascii
# File ses_quantcap.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_quantcap/ses_quantcap.csv
# Converting ses_pgbl_uf.csv: Detected ascii
# File ses_pgbl_uf.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_pgbl_uf/ses_pgbl_uf.csv
# Converting Ses_limite_ret.csv: Detected ascii
# File Ses_limite_ret.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_limite_ret/Ses_limite_ret.csv
# Converting SES_ValoresMovRamos.csv: Detected ascii
# File SES_ValoresMovRamos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/SES_ValoresMovRamos/SES_ValoresMovRamos.csv
# Converting ses_transferenciasexternas.csv: Detected ISO-8859-1
# File ses_transferenciasexternas.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/ses_transferenciasexternas/ses_transferenciasexternas.csv
# Converting Ses_part_acion.csv: Detected Windows-1252
# File Ses_part_acion.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_part_acion/Ses_part_acion.csv
# Converting Ses_pl_margem.csv: Detected ascii
# File Ses_pl_margem.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_pl_margem/Ses_pl_margem.csv
# Converting Ses_campos.csv: Detected Windows-1252
# File Ses_campos.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/Ses_campos/Ses_campos.csv
# Converting SES_UF2.csv: Detected ascii
# File SES_UF2.csv converted to utf-8 and saved at /Users/jean.barkoczy/Documents/BaseCompleta/Trata/SES_UF2/SES_UF2.csv
